# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthkumar2143/2024_STAT_ML_assignments/blob/main/STML_Project(Heart_failure)_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/sample_data/heart[2].csv')
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
target=data['HeartDisease']
target.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64

# %%
x=data.drop(['HeartDisease'],axis=1)
x.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope
# 0              N      0.0       Up
# 1              N      1.0     Flat
# 2              N      0.0       Up
# 3              Y      1.5     Flat
# 4              N      0.0       Up

# %%
x.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# dtype: int64

# %%
data = data.replace(['M'], 1)
data= data.replace(['F'], 0)
data=data.replace(['Normal'], 1)
data=data.replace(['ST'], 0)
data=data.replace(['Up'],1)
data=data.replace(['Flat'],0)
data=data.replace(['Down'],2)
data=data.replace(['ATA'],1)
data=data.replace(['NAP'],2)
data=data.replace(['ASY'],0
data=data.replace(['Y'],1)
data=data.replace(['N'],0)
data=data.replace(['LVH'],2)
data=data.replace(['TA'],3)
print(data)
x.isnull().sum()
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           0
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           2
# 917   38    1              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0      172               0      0.0         1             0
# 1      156               0      1.0         0             1
# 2       98               0      0.0         1             0
# 3      108               1      1.5         0             1
# 4      122               0      0.0         1             0
# ..     ...             ...      ...       ...           ...
# 913    132               0      1.2         0             1
# 914    141               0      3.4         0             1
# 915    115               1      1.2         0             1
# 916    174               0      0.0         0             1
# 917    173               0      0.0         1             0
#
# [918 rows x 12 columns]
# <ipython-input-6-599cc049384e>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data= data.replace(['F'], 0)
# <ipython-input-6-599cc049384e>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data=data.replace(['Down'],2)
# <ipython-input-6-599cc049384e>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data=data.replace(['N'],0)
# <ipython-input-6-599cc049384e>:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data=data.replace(['LVH'],2)
# <ipython-input-6-599cc049384e>:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data=data.replace(['TA'],3)
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# dtype: int64

# %%
data = data.replace(['M'], 1)
data= data.replace(['F'], 0)
data=data.replace(['Normal'], 1)
data=data.replace(['ST'], 0)
data=data.replace(['Up'],1)
data=data.replace(['Flat'],0)
data=data.replace(['Down'],2)
data=data.replace(['ATA'],1)
data=data.replace(['NAP'],2)
data=data.replace(['ASY'],0)
data=data.replace(['Y'],1)
data=data.replace(['N'],0)
data=data.replace(['LVH'],2)
data=data.replace(['TA'],3)
print(data)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           0
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           2
# 917   38    1              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0      172               0      0.0         1             0
# 1      156               0      1.0         0             1
# 2       98               0      0.0         1             0
# 3      108               1      1.5         0             1
# 4      122               0      0.0         1             0
# ..     ...             ...      ...       ...           ...
# 913    132               0      1.2         0             1
# 914    141               0      3.4         0             1
# 915    115               1      1.2         0             1
# 916    174               0      0.0         0             1
# 917    173               0      0.0         1             0
#
# [918 rows x 12 columns]

# %% [markdown]
# Before resampling data

# %%
x.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# dtype: object

# %%
print(x)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# 1      156              N      1.0     Flat
# 2       98              N      0.0       Up
# 3      108              Y      1.5     Flat
# 4      122              N      0.0       Up
# ..     ...            ...      ...      ...
# 913    132              N      1.2     Flat
# 914    141              N      3.4     Flat
# 915    115              Y      1.2     Flat
# 916    174              N      0.0     Flat
# 917    173              N      0.0       Up
#
# [918 rows x 11 columns]

# %%
x = x.replace(['M'], 1)
x = x.replace(['F'], 0)
x = x.replace(['Normal'], 1)
x = x.replace(['ST'], 0)
x = x.replace(['Up'],1)
x = x.replace(['Flat'],0)
x = x.replace(['Down'],2)
x = x.replace(['ATA'],1)
x = x.replace(['NAP'],2)
x = x.replace(['ASY'],0)
x = x.replace(['Y'],1)
x = x.replace(['N'],0)
x = x.replace(['LVH'],2)
x = x.replace(['TA'],3)

for col in x.columns:
  if x[col].dtype == 'object':
    try:
      x[col] = x[col].astype('int64')
    except ValueError:
      x[col] = x[col].astype('float64').astype('int64')
# Out:
# <ipython-input-15-b661d0045583>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(['F'], 0)
# <ipython-input-15-b661d0045583>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(['Down'],2)
# <ipython-input-15-b661d0045583>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(['N'],0)
# <ipython-input-15-b661d0045583>:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(['LVH'],2)
# <ipython-input-15-b661d0045583>:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(['TA'],3)

# %%
for col in x.columns:
  if x[col].dtype == 'object':
    try:
      x[col] = x[col].astype('int64')
    except ValueError:
      x[col] = x[col].astype('float64').astype('int64')

# %%
print(data.isnull())
# Out:
#        Age    Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    False  False          False      False        False      False
# 1    False  False          False      False        False      False
# 2    False  False          False      False        False      False
# 3    False  False          False      False        False      False
# 4    False  False          False      False        False      False
# ..     ...    ...            ...        ...          ...        ...
# 913  False  False          False      False        False      False
# 914  False  False          False      False        False      False
# 915  False  False          False      False        False      False
# 916  False  False          False      False        False      False
# 917  False  False          False      False        False      False
#
#      RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0         False  False           False    False     False         False
# 1         False  False           False    False     False         False
# 2         False  False           False    False     False         False
# 3         False  False           False    False     False         False
# 4         False  False           False    False     False         False
# ..          ...    ...             ...      ...       ...           ...
# 913       False  False           False    False     False         False
# 914       False  False           False    False     False         False
# 915       False  False           False    False     False         False
# 916       False  False           False    False     False         False
# 917       False  False           False    False     False         False
#
# [918 rows x 12 columns]

# %%
x.dtypes
# Out:
# Age                 int64
# Sex                 int64
# ChestPainType       int64
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG          int64
# MaxHR               int64
# ExerciseAngina      int64
# Oldpeak           float64
# ST_Slope            int64
# dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 79.0 KB

# %%
x.describe()
# Out:
#               Age         Sex  ChestPainType   RestingBP  Cholesterol  \
# count  918.000000  918.000000     918.000000  918.000000   918.000000
# mean    53.510893    0.789760       0.781046  132.396514   198.799564
# std      9.432617    0.407701       0.956519   18.514154   109.384145
# min     28.000000    0.000000       0.000000    0.000000     0.000000
# 25%     47.000000    1.000000       0.000000  120.000000   173.250000
# 50%     54.000000    1.000000       0.000000  130.000000   223.000000
# 75%     60.000000    1.000000       2.000000  140.000000   267.000000
# max     77.000000    1.000000       3.000000  200.000000   603.000000
#
#         FastingBS  RestingECG       MaxHR  ExerciseAngina     Oldpeak  \
# count  918.000000  918.000000  918.000000      918.000000  918.000000
# mean     0.233115    1.010893  136.809368        0.404139    0.887364
# std      0.423046    0.631671   25.460334        0.490992    1.066570
# min      0.000000    0.000000   60.000000        0.000000   -2.600000
# 25%      0.000000    1.000000  120.000000        0.000000    0.000000
# 50%      0.000000    1.000000  138.000000        0.000000    0.600000
# 75%      0.000000    1.000000  156.000000        1.000000    1.500000
# max      1.000000    2.000000  202.000000        1.000000    6.200000
#
#          ST_Slope
# count  918.000000
# mean     0.567538
# std      0.618959
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %%
for clo in x.columns:
  print(x[clo].describe())
  print()
  print()
  print()
# Out:
# count    918.000000
# mean      53.510893
# std        9.432617
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64
#
#
#
# count    918.000000
# mean       0.789760
# std        0.407701
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Sex, dtype: float64
#
#
#
# count    918.000000
# mean       0.781046
# std        0.956519
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max        3.000000
# Name: ChestPainType, dtype: float64
#
#
#
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64
#
#
#
# count    918.000000
# mean     198.799564
# std      109.384145
# min        0.000000
# 25%      173.250000
# 50%      223.000000
# 75%      267.000000
# max      603.000000
# Name: Cholesterol, dtype: float64
#
#
#
# count    918.000000
# mean       0.233115
# std        0.423046
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: FastingBS, dtype: float64
#
#
#
# count    918.000000
# mean       1.010893
# std        0.631671
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: RestingECG, dtype: float64
#
#
#
# count    918.000000
# mean     136.809368
# std       25.460334
# min       60.000000
# 25%      120.000000
# 50%      138.000000
# 75%      156.000000
# max      202.000000
# Name: MaxHR, dtype: float64
#
#
#
# count    918.000000
# mean       0.404139
# std        0.490992
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: ExerciseAngina, dtype: float64
#
#
#
# count    918.000000
# mean       0.887364
# std        1.066570
# min       -2.600000
# 25%        0.000000
# 50%        0.600000
# 75%        1.500000
# max        6.200000
# Name: Oldpeak, dtype: float64
#
#
#
# count    918.000000
# mean       0.567538
# std        0.618959
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        2.000000
# Name: ST_Slope, dtype: float64

# %%
for clo in x.columns:
  print(x[clo].info())
  print()
  print()
  print()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: Sex
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: ChestPainType
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: RestingBP
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: Cholesterol
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: FastingBS
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: RestingECG
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: MaxHR
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: ExerciseAngina
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: Oldpeak
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    float64
# dtypes: float64(1)
# memory usage: 7.3 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: ST_Slope
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB
# None

# %%
for clo in x.columns:
  print(x[clo].value_counts())
  print()
  print()
  print()
# Out:
# Age
# 54    51
# 58    42
# 55    41
# 56    38
# 57    38
# 52    36
# 51    35
# 59    35
# 62    35
# 53    33
# 60    32
# 48    31
# 61    31
# 63    30
# 50    25
# 46    24
# 41    24
# 43    24
# 64    22
# 65    21
# 49    21
# 47    19
# 44    19
# 42    18
# 45    18
# 38    16
# 67    15
# 39    15
# 66    13
# 69    13
# 40    13
# 35    11
# 37    11
# 68    10
# 34     7
# 74     7
# 70     7
# 36     6
# 71     5
# 32     5
# 72     4
# 29     3
# 75     3
# 33     2
# 77     2
# 76     2
# 31     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64
#
#
#
# Sex
# 1    725
# 0    193
# Name: count, dtype: int64
#
#
#
# ChestPainType
# 0    496
# 2    203
# 1    173
# 3     46
# Name: count, dtype: int64
#
#
#
# RestingBP
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
#       ...
# 185      1
# 98       1
# 92       1
# 113      1
# 164      1
# Name: count, Length: 67, dtype: int64
#
#
#
# Cholesterol
# 0      172
# 254     11
# 223     10
# 220     10
# 230      9
#       ...
# 392      1
# 316      1
# 153      1
# 466      1
# 131      1
# Name: count, Length: 222, dtype: int64
#
#
#
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64
#
#
#
# RestingECG
# 1    552
# 2    188
# 0    178
# Name: count, dtype: int64
#
#
#
# MaxHR
# 150    43
# 140    41
# 120    36
# 130    33
# 160    25
#        ..
# 63      1
# 83      1
# 60      1
# 78      1
# 202     1
# Name: count, Length: 119, dtype: int64
#
#
#
# ExerciseAngina
# 0    547
# 1    371
# Name: count, dtype: int64
#
#
#
# Oldpeak
#  0.0    368
#  1.0     86
#  2.0     76
#  1.5     53
#  3.0     28
#  1.2     26
#  0.2     22
#  0.5     19
#  1.4     18
#  1.8     17
#  2.5     16
#  0.8     16
#  1.6     16
#  0.1     14
#  0.6     14
#  0.4     11
#  0.3     11
#  4.0      8
#  0.7      7
#  2.8      7
#  1.9      7
#  1.3      7
#  2.6      7
#  1.1      7
#  1.7      6
#  2.2      5
#  0.9      4
#  2.4      4
#  3.6      4
#  3.4      3
#  4.2      2
#  3.5      2
# -0.5      2
#  2.3      2
#  3.2      2
#  2.1      2
# -1.0      2
# -0.1      2
#  5.6      1
#  2.9      1
#  6.2      1
#  3.8      1
# -1.5      1
#  3.1      1
# -2.0      1
#  3.7      1
# -0.8      1
# -0.7      1
# -1.1      1
# -2.6      1
# -0.9      1
#  5.0      1
#  4.4      1
# Name: count, dtype: int64
#
#
#
# ST_Slope
# 0    460
# 1    395
# 2     63
# Name: count, dtype: int64

# %%
for clo in x.columns:
  print(x[clo].unique())
  print()
  print()
  print()
# Out:
# [40 49 37 48 54 39 45 58 42 38 43 60 36 44 53 52 51 56 41 32 65 35 59 50
#  47 31 46 57 55 63 66 34 33 61 29 62 28 30 74 68 72 64 69 67 73 70 77 75
#  76 71]
#
#
#
# [1 0]
#
#
#
# [1 2 0 3]
#
#
#
# [140 160 130 138 150 120 110 136 115 100 124 113 125 145 112 132 118 170
#  142 190 135 180 108 155 128 106  92 200 122  98 105 133  95  80 137 185
#  165 126 152 116   0 144 154 134 104 139 131 141 178 146 158 123 102  96
#  143 172 156 114 127 101 174  94 148 117 192 129 164]
#
#
#
# [289 180 283 214 195 339 237 208 207 284 211 164 204 234 273 196 201 248
#  267 223 184 288 215 209 260 468 188 518 167 224 172 186 254 306 250 177
#  227 230 294 264 259 175 318 216 340 233 205 245 194 270 213 365 342 253
#  277 202 297 225 246 412 265 182 218 268 163 529 100 206 238 139 263 291
#  229 307 210 329 147  85 269 275 179 392 466 129 241 255 276 282 338 160
#  156 272 240 393 161 228 292 388 166 247 331 341 243 279 198 249 168 603
#  159 190 185 290 212 231 222 235 320 187 266 287 404 312 251 328 285 280
#  192 193 308 219 257 132 226 217 303 298 256 117 295 173 315 281 309 200
#  336 355 326 171 491 271 274 394 221 126 305 220 242 347 344 358 169 181
#    0 236 203 153 316 311 252 458 384 258 349 142 197 113 261 310 232 110
#  123 170 369 152 244 165 337 300 333 385 322 564 239 293 407 149 199 417
#  178 319 354 330 302 313 141 327 304 286 360 262 325 299 409 174 183 321
#  353 335 278 157 176 131]
#
#
#
# [0 1]
#
#
#
# [1 0 2]
#
#
#
# [172 156  98 108 122 170 142 130 120  99 145 140 137 150 166 165 125 160
#  164 138 178 112 118 127 114 154 155  87 148 100 168 184 121 153 134  96
#  174 175 144  82 135 115 128 116  94 110  92 180 152 124 106 185 139 190
#  146 158 132 176 119 188 162 105  90 136 167 129 102 143 103  91 126  93
#  131 149 123 182 141  77 109 133 179 113 104  95  72  97 117  86  63 157
#   83  60  70 163  67  78  84 111  80 107 161  69  88  73 159 151 181 186
#  177 173 169 171 147  71 192 195 194 187 202]
#
#
#
# [0 1]
#
#
#
# [ 0.   1.   1.5  2.   3.   4.   0.5  2.5  5.   0.8  0.7  1.4  2.1  0.4
#   0.2  1.7  2.2  0.1  1.6  1.3  0.3  1.8  2.6 -0.9  2.8 -2.6 -1.5 -0.1
#   0.9  1.1  2.4 -1.  -1.1 -0.7 -0.8  3.7  1.2 -0.5 -2.   1.9  3.5  0.6
#   3.1  2.3  3.4  3.6  4.2  3.2  5.6  3.8  2.9  6.2  4.4]
#
#
#
# [1 0 2]

# %%
for clo in x.columns:
  if x[clo].dtype == 'int64':
    sns.histplot(x[clo], discrete=True)
  elif x[clo].dtype == 'float64':
    sns.histplot(x[clo])

  plt.show()

# %%
for col in x.columns:
    sns.countplot(x=col, data=x)
    plt.show()

# %%
for col in x.columns:
    sns.scatterplot(x=x[col],y=target)
    plt.show()

# %%
x.corr()
# Out:
#                      Age       Sex  ChestPainType  RestingBP  Cholesterol  \
# Age             1.000000  0.055750      -0.077150   0.254399    -0.095282
# Sex             0.055750  1.000000      -0.126559   0.005133    -0.200092
# ChestPainType  -0.077150 -0.126559       1.000000  -0.020647     0.067880
# RestingBP       0.254399  0.005133      -0.020647   1.000000     0.100893
# Cholesterol    -0.095282 -0.200092       0.067880   0.100893     1.000000
# FastingBS       0.198039  0.120076      -0.073151   0.070193    -0.260974
# RestingECG      0.007484 -0.071552       0.072537  -0.022656     0.196544
# MaxHR          -0.382045 -0.189186       0.289123  -0.112135     0.235792
# ExerciseAngina  0.215793  0.190664      -0.354727   0.155101    -0.034166
# Oldpeak         0.258612  0.105734      -0.177377   0.164803     0.050148
# ST_Slope       -0.093424 -0.066831       0.130916  -0.083418     0.007110
#
#                 FastingBS  RestingECG     MaxHR  ExerciseAngina   Oldpeak  \
# Age              0.198039    0.007484 -0.382045        0.215793  0.258612
# Sex              0.120076   -0.071552 -0.189186        0.190664  0.105734
# ChestPainType   -0.073151    0.072537  0.289123       -0.354727 -0.177377
# RestingBP        0.070193   -0.022656 -0.112135        0.155101  0.164803
# Cholesterol     -0.260974    0.196544  0.235792       -0.034166  0.050148
# FastingBS        1.000000   -0.087050 -0.131438        0.060451  0.052698
# RestingECG      -0.087050    1.000000  0.179276       -0.077500  0.020438
# MaxHR           -0.131438    0.179276  1.000000       -0.370425 -0.160691
# ExerciseAngina   0.060451   -0.077500 -0.370425        1.000000  0.408752
# Oldpeak          0.052698    0.020438 -0.160691        0.408752  1.000000
# ST_Slope        -0.043534    0.017641  0.246927       -0.253181 -0.097323
#
#                 ST_Slope
# Age            -0.093424
# Sex            -0.066831
# ChestPainType   0.130916
# RestingBP      -0.083418
# Cholesterol     0.007110
# FastingBS      -0.043534
# RestingECG      0.017641
# MaxHR           0.246927
# ExerciseAngina -0.253181
# Oldpeak        -0.097323
# ST_Slope        1.000000

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(x.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
target.value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 918 entries, 0 to 917
# Series name: HeartDisease
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    int64
# dtypes: int64(1)
# memory usage: 7.3 KB

# %%
target.describe()
# Out:
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: HeartDisease, dtype: float64

# %% [markdown]
# After resampling the data

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X,Y= smote.fit_resample(x,target)

# %%
for clo in X.columns:
  print(X[clo].describe())
  print()
  print()
  print()
# Out:
# count    1016.000000
# mean       53.235236
# std         9.301876
# min        28.000000
# 25%        47.000000
# 50%        54.000000
# 75%        60.000000
# max        77.000000
# Name: Age, dtype: float64
#
#
#
# count    1016.000000
# mean        0.755906
# std         0.429761
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Sex, dtype: float64
#
#
#
# count    1016.000000
# mean        0.785433
# std         0.934940
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max         3.000000
# Name: ChestPainType, dtype: float64
#
#
#
# count    1016.000000
# mean      132.187992
# std        18.246076
# min         0.000000
# 25%       120.000000
# 50%       130.000000
# 75%       140.000000
# max       200.000000
# Name: RestingBP, dtype: float64
#
#
#
# count    1016.000000
# mean      202.279528
# std       106.269184
# min         0.000000
# 25%       179.000000
# 50%       223.000000
# 75%       268.000000
# max       603.000000
# Name: Cholesterol, dtype: float64
#
#
#
# count    1016.000000
# mean        0.211614
# std         0.408654
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: FastingBS, dtype: float64
#
#
#
# count    1016.000000
# mean        1.001969
# std         0.618274
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: RestingECG, dtype: float64
#
#
#
# count    1016.000000
# mean      137.883858
# std        25.218070
# min        60.000000
# 25%       120.000000
# 50%       140.000000
# 75%       157.000000
# max       202.000000
# Name: MaxHR, dtype: float64
#
#
#
# count    1016.000000
# mean        0.367126
# std         0.482259
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: ExerciseAngina, dtype: float64
#
#
#
# count    1016.000000
# mean        0.843096
# std         1.036487
# min        -2.600000
# 25%         0.000000
# 50%         0.500000
# 75%         1.500000
# max         6.200000
# Name: Oldpeak, dtype: float64
#
#
#
# count    1016.000000
# mean        0.569882
# std         0.607862
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: ST_Slope, dtype: float64

# %%
for clo in X.columns:
  print(X[clo].info())
  print()
  print()
  print()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: Sex
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: ChestPainType
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: RestingBP
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: Cholesterol
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: FastingBS
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: RestingECG
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: MaxHR
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: ExerciseAngina
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: Oldpeak
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   float64
# dtypes: float64(1)
# memory usage: 8.1 KB
# None
#
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: ST_Slope
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB
# None

# %%
for clo in X.columns:
  print(X[clo].value_counts())
  print()
  print()
  print()
# Out:
# Age
# 54    60
# 58    44
# 51    43
# 57    43
# 55    42
# 56    42
# 52    40
# 53    39
# 59    38
# 62    35
# 48    34
# 60    33
# 61    33
# 63    30
# 50    30
# 43    28
# 46    28
# 41    28
# 45    26
# 64    25
# 65    23
# 44    23
# 49    22
# 47    22
# 42    19
# 67    18
# 39    18
# 38    17
# 37    13
# 66    13
# 69    13
# 40    13
# 35    12
# 68    10
# 34     7
# 74     7
# 36     7
# 70     7
# 71     5
# 32     5
# 72     4
# 29     3
# 75     3
# 33     2
# 77     2
# 76     2
# 31     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64
#
#
#
# Sex
# 1    768
# 0    248
# Name: count, dtype: int64
#
#
#
# ChestPainType
# 0    530
# 1    220
# 2    220
# 3     46
# Name: count, dtype: int64
#
#
#
# RestingBP
# 120    142
# 130    129
# 140    110
# 110     62
# 150     58
#       ...
# 80       1
# 96       1
# 185      1
# 92       1
# 103      1
# Name: count, Length: 77, dtype: int64
#
#
#
# Cholesterol
# 0      175
# 254     11
# 220     11
# 211     11
# 230     10
#       ...
# 347      1
# 468      1
# 491      1
# 355      1
# 359      1
# Name: count, Length: 227, dtype: int64
#
#
#
# FastingBS
# 0    801
# 1    215
# Name: count, dtype: int64
#
#
#
# RestingECG
# 1    628
# 2    195
# 0    193
# Name: count, dtype: int64
#
#
#
# MaxHR
# 150    43
# 140    42
# 120    38
# 130    33
# 160    27
#        ..
# 69      1
# 60      1
# 107     1
# 70      1
# 202     1
# Name: count, Length: 119, dtype: int64
#
#
#
# ExerciseAngina
# 0    643
# 1    373
# Name: count, dtype: int64
#
#
#
# Oldpeak
# 0.000000    403
# 1.000000     86
# 2.000000     76
# 1.500000     53
# 3.000000     28
#            ...
# 0.097682      1
# 0.289575      1
# 1.415609      1
# 0.346814      1
# 0.164310      1
# Name: count, Length: 116, dtype: int64
#
#
#
# ST_Slope
# 0    500
# 1    453
# 2     63
# Name: count, dtype: int64

# %%
for clo in X.columns:
  print(X[clo].unique())
  print()
  print()
  print()
# Out:
# [40 49 37 48 54 39 45 58 42 38 43 60 36 44 53 52 51 56 41 32 65 35 59 50
#  47 31 46 57 55 63 66 34 33 61 29 62 28 30 74 68 72 64 69 67 73 70 77 75
#  76 71]
#
#
#
# [1 0]
#
#
#
# [1 2 0 3]
#
#
#
# [140 160 130 138 150 120 110 136 115 100 124 113 125 145 112 132 118 170
#  142 190 135 180 108 155 128 106  92 200 122  98 105 133  95  80 137 185
#  165 126 152 116   0 144 154 134 104 139 131 141 178 146 158 123 102  96
#  143 172 156 114 127 101 174  94 148 117 192 129 164 168 151 107 121  97
#  161 119 111 173 103]
#
#
#
# [289 180 283 214 195 339 237 208 207 284 211 164 204 234 273 196 201 248
#  267 223 184 288 215 209 260 468 188 518 167 224 172 186 254 306 250 177
#  227 230 294 264 259 175 318 216 340 233 205 245 194 270 213 365 342 253
#  277 202 297 225 246 412 265 182 218 268 163 529 100 206 238 139 263 291
#  229 307 210 329 147  85 269 275 179 392 466 129 241 255 276 282 338 160
#  156 272 240 393 161 228 292 388 166 247 331 341 243 279 198 249 168 603
#  159 190 185 290 212 231 222 235 320 187 266 287 404 312 251 328 285 280
#  192 193 308 219 257 132 226 217 303 298 256 117 295 173 315 281 309 200
#  336 355 326 171 491 271 274 394 221 126 305 220 242 347 344 358 169 181
#    0 236 203 153 316 311 252 458 384 258 349 142 197 113 261 310 232 110
#  123 170 369 152 244 165 337 300 333 385 322 564 239 293 407 149 199 417
#  178 319 354 330 302 313 141 327 304 286 360 262 325 299 409 174 183 321
#  353 335 278 157 176 131 189 148 296 375 359]
#
#
#
# [0 1]
#
#
#
# [1 0 2]
#
#
#
# [172 156  98 108 122 170 142 130 120  99 145 140 137 150 166 165 125 160
#  164 138 178 112 118 127 114 154 155  87 148 100 168 184 121 153 134  96
#  174 175 144  82 135 115 128 116  94 110  92 180 152 124 106 185 139 190
#  146 158 132 176 119 188 162 105  90 136 167 129 102 143 103  91 126  93
#  131 149 123 182 141  77 109 133 179 113 104  95  72  97 117  86  63 157
#   83  60  70 163  67  78  84 111  80 107 161  69  88  73 159 151 181 186
#  177 173 169 171 147  71 192 195 194 187 202]
#
#
#
# [0 1]
#
#
#
# [ 0.          1.          1.5         2.          3.          4.
#   0.5         2.5         5.          0.8         0.7         1.4
#   2.1         0.4         0.2         1.7         2.2         0.1
#   1.6         1.3         0.3         1.8         2.6        -0.9
#   2.8        -2.6        -1.5        -0.1         0.9         1.1
#   2.4        -1.         -1.1        -0.7        -0.8         3.7
#   1.2        -0.5        -2.          1.9         3.5         0.6
#   3.1         2.3         3.4         3.6         4.2         3.2
#   5.6         3.8         2.9         6.2         4.4         0.1069875
#   1.83767086  0.04114047  0.17326862  0.96008581  0.17760312  0.34681398
#   1.41560944  0.28957514  0.09768151  0.29568002  1.24983633  1.13993499
#   1.1878481   0.16116522  1.54880855  1.49192571  0.34139819  0.65580755
#   0.10530829  1.59338321  0.56186572  0.72308525  0.44168991  2.13448964
#   0.52741231  1.34484525  1.27485431  0.17207254  1.1816728   0.67754497
#   0.4757565   0.01218892  0.09790401  1.64627087  0.86391863  0.14155965
#   0.11099404  0.53412778  0.55062052  0.24960369  0.37980625  1.09509962
#   1.35743822  0.64369518  0.33957519  0.53071203  0.00823419  0.56520007
#   0.89636844  0.06717173  0.2732225   1.43023222  0.03829961  1.07537242
#   0.97034614 -0.26384928  0.62041402  1.2318143   0.44847241  0.35182837
#   0.82134131  0.16431004]
#
#
#
# [1 0 2]

# %%
for clo in X.columns:
  if X[clo].dtype == 'int64':
    sns.histplot(X[clo], discrete=True)
  elif X[clo].dtype == 'float64':
    sns.histplot(X[clo])

  plt.show()

# %%
for col in X.columns:
    sns.countplot(x=col, data=X)
    plt.show()

# %%
for col in X.columns:
    sns.scatterplot(x=X[col],y=Y)
    plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(X.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
Y.value_counts()
# Out:
# HeartDisease
# 0    508
# 1    508
# Name: count, dtype: int64

# %%
Y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1016 entries, 0 to 1015
# Series name: HeartDisease
# Non-Null Count  Dtype
# --------------  -----
# 1016 non-null   int64
# dtypes: int64(1)
# memory usage: 8.1 KB

# %%
Y.describe()
# Out:
# count    1016.000000
# mean        0.500000
# std         0.500246
# min         0.000000
# 25%         0.000000
# 50%         0.500000
# 75%         1.000000
# max         1.000000
# Name: HeartDisease, dtype: float64

# %% [markdown]
# Splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 332   38    1              2        100            0          0           1
# 708   54    1              0        110          206          0           2
# 218   55    1              1        140          196          0           1
# 425   60    1              1        160          267          1           0
# 448   63    1              0        160          230          1           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 106   48    0              0        120          254          0           0
# 270   45    1              0        120          225          0           1
# 860   60    1              0        130          253          0           1
# 435   60    1              0        152            0          0           0
# 102   40    0              0        150          392          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 332    179               0     -1.1         1
# 708    108               1      0.0         0
# 218    150               0      0.0         1
# 425    157               0      0.5         0
# 448    105               1      1.0         0
# ..     ...             ...      ...       ...
# 106    110               0      0.0         1
# 270    140               0      0.0         1
# 860    144               1      1.4         1
# 435    118               1      0.0         1
# 102    130               0      2.0         0
#
# [812 rows x 11 columns]

# %% [markdown]
# Perceptron

# %%
from sklearn.linear_model import Perceptron
pm=Perceptron()
pm.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
yp=pm.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[ 11  77]
#  [  3 113]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.12      0.22        88
#            1       0.59      0.97      0.74       116
#
#     accuracy                           0.61       204
#    macro avg       0.69      0.55      0.48       204
# weighted avg       0.68      0.61      0.51       204

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.6078431372549019

# %% [markdown]
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yp = lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[74 14]
#  [19 97]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        88
#            1       0.87      0.84      0.85       116
#
#     accuracy                           0.84       204
#    macro avg       0.83      0.84      0.84       204
# weighted avg       0.84      0.84      0.84       204

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.8382352941176471

# %% [markdown]
# Support Vector Machine

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
yp=sv.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_test,yp))
# Out:
# [[69 19]
#  [49 67]]

# %%
cm = confusion_matrix(y_test, yp)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.78      0.67        88
#            1       0.78      0.58      0.66       116
#
#     accuracy                           0.67       204
#    macro avg       0.68      0.68      0.67       204
# weighted avg       0.70      0.67      0.67       204

# %%
print(accuracy_score(y_test,yp))
# Out:
# 0.6666666666666666

# %% [markdown]
# K-NN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=x_train.shape[1]))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6370 - loss: 3.0963
# Epoch 2/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6976 - loss: 0.8525
# Epoch 3/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7249 - loss: 0.6144
# Epoch 4/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 0.5616
# Epoch 5/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7186 - loss: 0.5505
# Epoch 6/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7588 - loss: 0.5010
# Epoch 7/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8166 - loss: 0.4535
# Epoch 8/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7400 - loss: 0.5380
# Epoch 9/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7800 - loss: 0.4891
# Epoch 10/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8035 - loss: 0.4331

# %%
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.3994
# Accuracy: 82.84

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 61  27]
#  [  8 108]]

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
